# %% [markdown]
# # Mock Ocean Features
#
# This notebook describes the synthetic SST, front and current assumptions used in v0.1. Data is demo-only and not observed ocean data.

# %%
bbox = {'north': -32.0, 'south': -36.5, 'west': 150.5, 'east': 154.5}
bbox
