# %% [markdown]
# # Future ML Dataset Design
#
# Future datasets should separate presence observations, background samples and user catch/no-catch logs. Catch reports are biased by where people fish and absence is not true absence.

# %%
columns = ['species_id', 'timestamp', 'lat', 'lon', 'sst_c', 'front_strength', 'current_speed', 'depth_m', 'distance_to_shelf_km', 'label']
columns
