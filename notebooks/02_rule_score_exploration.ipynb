# %% [markdown]
# # Rule Score Exploration
#
# Use this notebook to explore how SST, fronts, currents and depth affect synthetic pelagic scores.

# %%
example = {'sst_c': 22.0, 'gradient_strength': 1.5, 'current_speed_m_s': 0.7, 'poi_type': 'canyon', 'depth_class': 'deep'}
example
